# %%
from cdp_data import CDPInstances, datasets
import pandas as pd
import numpy as np
import spacy

# %%
# load custom model
nlp_custom = spacy.load("local-interest-groups-ner-model-v1/")
# Out:
# /Users/kellyzwang/miniconda3/envs/sig-cdp/lib/python3.9/site-packages/spacy/util.py:877: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.5 and may not be 100% compatible with the current version (3.4.4). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
truth_df = pd.read_csv('ground truth dataset.csv')
truth_df.head()
# Out:
#                                                 text  \
# 0  Good morning. As you said, I'm a downtown resi...
# 1  Down morning. I'm chair of tree pack. It's dis...
# 2  So Doug and Andrew if you are out there, call ...
# 3  Thank you. Hi, I just want to bring attention ...
# 4  Yes, I'm here. I'm unmuted, it appears. Yes. O...
#
#                                                ent_1  \
# 0                                                NaN
# 1                                                NaN
# 2  Richard Ellison. I'm a retired community colle...
# 3                  Howard Gale with Seattle stop.org
# 4                                                NaN
#
#                      label_1 ent_2 label_2
# 0                        NaN   NaN     NaN
# 1                        NaN   NaN     NaN
# 2                     PERSON   NaN     NaN
# 3  PERSON-AFFLIATED-WITH-ORG   NaN     NaN
# 4                        NaN   NaN     NaN

# %% [markdown]
# ## Apply the custom NER model

# %%
# use the custom model to recognize entities in the 28 examples

df = pd.read_json('local-interest-groups-irr-annotation-set.jsonl', lines=True)

ner_result = []
for _, row in df.iterrows():
    doc = nlp_custom(row['text'])
    entities = list(doc.ents)
    
    if len(entities) >= 2:
        ner_result.append([row['text'], entities[0].text, entities[0].label_, 
                           entities[1].text, entities[1].label_])
    elif len(entities) == 1:
        ner_result.append([row['text'], entities[0].text, entities[0].label_, np.nan, np.nan])
    else:
        ner_result.append([row['text'], np.nan, np.nan, np.nan, np.nan])
        

ner_df = pd.DataFrame(ner_result, columns=["text", "predicted_ent_1", "named_entity_type_1", 
                                           "predicted_ent_2", "named_entity_type_2"])
ner_df
# Out:
#                                                  text  \
# 0   Good morning. As you said, I'm a downtown resi...
# 1   Down morning. I'm chair of tree pack. It's dis...
# 2   So Doug and Andrew if you are out there, call ...
# 3   Thank you. Hi, I just want to bring attention ...
# 4   Yes, I'm here. I'm unmuted, it appears. Yes. O...
# 5   Good afternoon, Council. Thank you for the cha...
# 6   Good morning, Pete her. Good morning. I'm in d...
# 7   Jacob, good morning. Hi. I'm Jacob sheer, Orga...
# 8   Good morning. I am Madison, resident of distri...
# 9   Good morning. I want to address your agenda it...
# 10  Good morning. My name is Paul Casey and I have...
# 11  My name is Catherine Six and I'm the executive...
# 12  Hello, councilman Hollander. Another members o...
# 13  My name is Andrea Diggs. I am the executive di...
# 14  Good evening. I would like to begin tonight by...
# 15  How y'all doing every one of you who know me B...
# 16  Hello.  I live with my family and district 7 a...
# 17  Hello, my name is Steven Bartlett. And I'm her...
# 18  Good afternoon, Greg McConnell, I'm here on be...
# 19  My name is Gamila, I have times and I'm an Org...
# 20  My name is Carmen, I live director of housing ...
# 21  Efz Ning, members of the Oakland City Council,...
# 22  My name is Juanita Douglas t senior constructi...
# 23  Hi, my name is Liz Suk, I Aoep the executive d...
# 24  Nick Peraino with Seiu 1021. I also want to th...
# 25  Good morning, chair and staff and members of t...
# 26  Hi, everyone, my name is Jessie Nguyen, I'm sp...
# 27  Good afternoon, members of committee, my name ...
#
#                                       predicted_ent_1  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Richard Ellison. I'm a retired community colle...
# 3                                                 NaN
# 4                                                 NaN
# 5   Christy Heffaker. And I have proudly worked fo...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  My name is Paul Casey and I have lived in West...
# 11  Catherine Six and I'm the executive director o...
# 12                                                NaN
# 13  Andrea Diggs. I am the executive director of S...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  my name is Steven Bartlett. And I'm here, repr...
# 18                                                NaN
# 19  Gamila, I have times and I'm an Organizer with...
# 20  Carmen, I live director of housing at the East...
# 21  Lee and I am a member of the International lon...
# 22  Juanita Douglas t senior construction manager ...
# 23  Liz Suk, I Aoep the executive director for Oak...
# 24  my name is Danny comment that I'm a small prop...
# 25                                                NaN
# 26  Jessie Nguyen, I'm speaking as a district 2 re...
# 27  Karely Ordaz t chief of staff at the unity Cou...
#
#           named_entity_type_1  \
# 0                         NaN
# 1                         NaN
# 2                      PERSON
# 3                         NaN
# 4                         NaN
# 5   PERSON-AFFLIATED-WITH-ORG
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10  PERSON-AFFLIATED-WITH-ORG
# 11  PERSON-AFFLIATED-WITH-ORG
# 12                        NaN
# 13  PERSON-AFFLIATED-WITH-ORG
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                     PERSON
# 18                        NaN
# 19  PERSON-AFFLIATED-WITH-ORG
# 20  PERSON-AFFLIATED-WITH-ORG
# 21  PERSON-AFFLIATED-WITH-ORG
# 22  PERSON-AFFLIATED-WITH-ORG
# 23  PERSON-AFFLIATED-WITH-ORG
# 24  PERSON-AFFLIATED-WITH-ORG
# 25                        NaN
# 26  PERSON-AFFLIATED-WITH-ORG
# 27                     PERSON
#
#                                       predicted_ent_2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Flanigan, please Unmute yourself, you - may be...
# 20  Rachel Beck, a district one resident, first th...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
#
#           named_entity_type_2
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19  PERSON-AFFLIATED-WITH-ORG
# 20                     PERSON
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN

# %% [markdown]
# ## Model Evaluation

# %%
# keep track of "perfect accuracy" by just comparing the text of each found entity

# calculate the accuracy of the model based on string comparison between the predicted 
# entities and the ground truth dataset (truth_df)

#def any_label_at_all(truth_df, ner_result_df):

def model_evaluation_exact_span(truth_df, ner_result_df):

    total_predictions = len(truth_df)
    correct_predictions = 0 

    for i, truth_row in truth_df.iterrows():
        ner_result_row = ner_result_df.loc[i]
    
    
        if (truth_row['ent_1'] == ner_result_row['predicted_ent_1']) and (truth_row['ent_2'] == ner_result_row['predicted_ent_2']):
            correct_predictions += 1

        # if truth_df doesn't have a value for either ent_1 or ent_2 and the model doesn't find anything
        if (pd.isna(truth_row['ent_1']) and pd.isna(truth_row['ent_2'])) and (pd.isna(ner_result_row['predicted_ent_1']) and pd.isna(ner_result_row['predicted_ent_2'])):
            correct_predictions += 1
    

    accuracy = (correct_predictions / total_predictions) * 100

    print(f"{accuracy:.2f}% of the ground truth dataset was predicted correctly.")

model_evaluation_exact_span(truth_df, ner_df)


#def model_evaluation_label_accuracy:
# Out:
# 32.14% of the ground truth dataset was predicted correctly.

# %% [markdown]
# ## writing a function that increases accuracy

# %%
# the custom model finds the general area or maybe one of the entities we want

# write a wrapper function for getting better results, combine with spacy's model

nlp_spacy = spacy.load("en_core_web_sm")

# The NERs we are interested in (for spacy)
ners = ['PERSON', 'ORG', 'NORP']

ner_result = []
for i, row in df.iterrows():
    
    doc_custom = nlp_custom(row['text'])
    
    entities = list(doc_custom.ents)
    
    for j, e in enumerate(entities):
        doc_spacy = nlp_spacy(str(e))        
        entities_spacy = [ent for ent in doc_spacy.ents if ent.label_ in ners]
        
        print("e:", e)
        
        if entities_spacy:
            person_ent = None
            org_ent = None
            for ent in entities_spacy:
                if ent.label_ == "PERSON":
                    person_ent = ent
                elif ent.label_ in ["ORG", "NORP"]:
                    org_ent = ent
                    
            print("person_ent", person_ent)
            
            if person_ent:
                start = e.start_char + person_ent.start_char
                end = e.end_char
                
                # update the span to start with person's name
                entities[j] = doc_custom.char_span(start, end, label='PERSON')
                print("person_ent, start_char and end_char:", person_ent.start_char, person_ent.end_char)
                print("e, start_char and end_char", e.start_char, e.end_char)

                print("entities[j]", entities[j])
        
    
    if entities:
        if len(entities) >= 2:
            ner_result.append([row['text'], entities[0].text, entities[0].label_, 
                           entities[1].text, entities[1].label_])
        elif len(entities) == 1:
            ner_result.append([row['text'], entities[0].text, entities[0].label_, np.nan, np.nan])
    else:
        ner_result.append([row['text'], np.nan, np.nan, np.nan, np.nan])
        

new_ner_df = pd.DataFrame(ner_result, columns=["text", "predicted_ent_1", "named_entity_type_1", 
                                           "predicted_ent_2", "named_entity_type_2"])
new_ner_df
# Out:
# e: Richard Ellison. I'm a retired community college professor of biology and environmental science. And also a board member of a political action committee for trees.
# person_ent Richard Ellison
# person_ent, start_char and end_char: 0 15
# e, start_char and end_char 107 270
# entities[j] Richard Ellison. I'm a retired community college professor of biology and environmental science. And also a board member of a political action committee for trees.
# e: Christy Heffaker. And I have proudly worked for the city by serving Seattle City Light for the last 28 years. And I wanted to just bring to the attention of the council the fact that since I was hired in 1993, one of my proudest things about working for the city of Seattle was the city value, diversity, tolerance, and inclusivity.
# person_ent None
# e: My name is Paul Casey and I have lived in West Seattle
# person_ent Paul Casey
# person_ent, start_char and end_char: 11 21
# e, start_char and end_char 14 68
# entities[j] Paul Casey and I have lived in West Seattle
# e: Catherine Six and I'm the executive director of educational Justice. Our mission is to work to end educational. Inequity. In Louisville by pairing a fifth through. Eighth grade student with a high achieving high school student for long-term academic mentorship aimed at both improving academic performance and providing a meaningful student leadership experience.
# person_ent Catherine Six
# person_ent, start_char and end_char: 0 13
# e, start_char and end_char 11 374
# entities[j] Catherine Six and I'm the executive director of educational Justice. Our mission is to work to end educational. Inequity. In Louisville by pairing a fifth through. Eighth grade student with a high achieving high school student for long-term academic mentorship aimed at both improving academic performance and providing a meaningful student leadership experience.
# e: Andrea Diggs. I am the executive director of Sacred Heart School for the Arts. We provide Arts education integration during the school day as well as after school instruction and music, dance drama and visual arts to students throughout the greater Global Community. Our programming has been in existence for 51 years and is open to anyone in the community ages 3 and up. And we have recently in the last two years, expanded our reach to a
# person_ent Andrea Diggs
# person_ent, start_char and end_char: 0 12
# e, start_char and end_char 11 450
# entities[j] Andrea Diggs. I am the executive director of Sacred Heart School for the Arts. We provide Arts education integration during the school day as well as after school instruction and music, dance drama and visual arts to students throughout the greater Global Community. Our programming has been in existence for 51 years and is open to anyone in the community ages 3 and up. And we have recently in the last two years, expanded our reach to a
# e: my name is Steven Bartlett. And I'm here, representing the food and neighbor neighborhood Coalition
# person_ent Steven Bartlett
# person_ent, start_char and end_char: 11 26
# e, start_char and end_char 7 106
# entities[j] Steven Bartlett. And I'm here, representing the food and neighbor neighborhood Coalition
# e: Gamila, I have times and I'm an Organizer with the Emerald new deal and for more than two years, we've been working hard on this historic measure the fulfill the intentions of measure D that Legalize marijuana to support the impacted communities and repair some of the harm on the war on drugs, this was meant to happen in 2004 it did not, we should not delay it my NER, I urge you the vote yes to put the new Emd Rald new deal on the ballot and make history, we should be at the forefront to realize equity through Cannabis and restore the community and use the funds to support them, please vote yes to put the Emerald new - deal ton ballot and realize the intentions of measure Z that Legalize marijuana and wanted this money to persuade in repairing and fixing the harms on the community, thank you, I yield the rest of my time.
# person_ent Legalize
# person_ent, start_char and end_char: 688 696
# e, start_char and end_char 11 843
# entities[j] Legalize marijuana and wanted this money to persuade in repairing and fixing the harms on the community, thank you, I yield the rest of my time.
# e: Flanigan, please Unmute yourself, you - may begin your comments.
# person_ent None
# e: John, I'm a resident of district 2
# person_ent John
# person_ent, start_char and end_char: 0 4
# e, start_char and end_char 988 1022
# entities[j] John, I'm a resident of district 2
# e: Carmen, I live director of housing at the East Bay
# e: Rachel Beck, a district one resident, first things to all the would've on all your work on preparing election materials, if I'm exhausted looks at this agenda, I can - only imagine what it must be for you, regarding Mid-Cycle budget amendment, shootings and Homicides have been done for about 7 months, despite staffing levels, giving Opd an additional
# person_ent Opd
# person_ent, start_char and end_char: 335 338
# e, start_char and end_char 1688 2040
# entities[j] Opd an additional
# e: Lee and I am a member of the International long shore and warehouse unions in northern California District Council and speaking today on the Council's behalf. The final Howard terminal environmental impact report - clearly tells us the real estate ballpark development will cause grave impacts to our working waterfront and to the residents and businesses in West Oakland
# person_ent Lee
# person_ent, start_char and end_char: 0 3
# e, start_char and end_char 58 429
# entities[j] Lee and I am a member of the International long shore and warehouse unions in northern California District Council and speaking today on the Council's behalf. The final Howard terminal environmental impact report - clearly tells us the real estate ballpark development will cause grave impacts to our working waterfront and to the residents and businesses in West Oakland
# e: Juanita Douglas t senior construction manager and hands-on instructor for rising son center for opportunity. I work 15 years as a commercial carpenter and another 15 years as a land surveyor, rising son is an Oakland based core apprenticeship readiness program, we help recruit Oakland residents for Union trades, 50% of our cohorts that are ran by rising son are female, we have a placement rate of 70 plus percent and a retention rate of approximately 65%, with this proposition, we could continue to place black Oakland residents and Underrepresented populations and keep them working and help feed and House their families with this resolution.
# person_ent Juanita Douglas
# person_ent, start_char and end_char: 0 15
# e, start_char and end_char 11 659
# entities[j] Juanita Douglas t senior construction manager and hands-on instructor for rising son center for opportunity. I work 15 years as a commercial carpenter and another 15 years as a land surveyor, rising son is an Oakland based core apprenticeship readiness program, we help recruit Oakland residents for Union trades, 50% of our cohorts that are ran by rising son are female, we have a placement rate of 70 plus percent and a retention rate of approximately 65%, with this proposition, we could continue to place black Oakland residents and Underrepresented populations and keep them working and help feed and House their families with this resolution.
# e: Liz Suk, I Aoep the executive director for Oakland rising and I'm calling in to speak about the progressive business tax. I want to again also echo the thanks by grace to Council President BAS and Councilmembers Thao and Fife on the ongoing leadership for the progressive business tax, particularly I want to lift up Council President BAS and her two years of work on bringing this business tax to fruition
# person_ent BAS
# person_ent, start_char and end_char: 335 338
# e, start_char and end_char 15 421
# entities[j] BAS and her two years of work on bringing this business tax to fruition
# e: my name is Danny comment that I'm a small property owner, I support the reform to the tax, the one thing that I wanted to point out, I own one duplex and I don't see why you would tax me as a small property owner the same way you would tax a corporation that has millions of dollars in revenue so, I wanted to comment, ask that there be a carve out for small property owners so that you don't tax us as if we were large corporations, and that's it.
# person_ent Danny
# person_ent, start_char and end_char: 11 16
# e, start_char and end_char 806 1254
# entities[j] Danny comment that I'm a small property owner, I support the reform to the tax, the one thing that I wanted to point out, I own one duplex and I don't see why you would tax me as a small property owner the same way you would tax a corporation that has millions of dollars in revenue so, I wanted to comment, ask that there be a carve out for small property owners so that you don't tax us as if we were large corporations, and that's it.
# e: Jessie Nguyen, I'm speaking as a district 2 resident, a member TOF real people's Fund ask a small food business owner, I'm joining today to support city council in passing the Unifid proposal for a progressive and equitable business tax on the November ballot. As a business owner without generational wealth, access to capital and lack of culturally relevant resources, starting and trying to stay on my business was one of the Scariest Thins I've ever done, while faced with so many systemic barriers, all I wish today see was the potential to build my own self-determination and wealth for my family on our own terms. As entrepreneurs, we tap into the dream of building a business as a portal to express our fullest selves, making and producing and cooking in ways that honor our wholeness. We see these examples of culture and art manifest in beautiful ways in every corner of Oakland but we entrepreneurs condition do this when there are decades of Disinvestment and discriminatory policies. Small businesses are a natural entry point for the city of Oakland to bolster economic security, it is clear that racial inequality is tied closely with geography in Oakland, it is clear that the city of Oakland lacks the tools necessary to provide essentially services and resources to the small business owners and entrepreneurs of Oakland who need it the most especially now.
# person_ent Jessie Nguyen
# person_ent, start_char and end_char: 0 13
# e, start_char and end_char 25 1400
# entities[j] Jessie Nguyen, I'm speaking as a district 2 resident, a member TOF real people's Fund ask a small food business owner, I'm joining today to support city council in passing the Unifid proposal for a progressive and equitable business tax on the November ballot. As a business owner without generational wealth, access to capital and lack of culturally relevant resources, starting and trying to stay on my business was one of the Scariest Thins I've ever done, while faced with so many systemic barriers, all I wish today see was the potential to build my own self-determination and wealth for my family on our own terms. As entrepreneurs, we tap into the dream of building a business as a portal to express our fullest selves, making and producing and cooking in ways that honor our wholeness. We see these examples of culture and art manifest in beautiful ways in every corner of Oakland but we entrepreneurs condition do this when there are decades of Disinvestment and discriminatory policies. Small businesses are a natural entry point for the city of Oakland to bolster economic security, it is clear that racial inequality is tied closely with geography in Oakland, it is clear that the city of Oakland lacks the tools necessary to provide essentially services and resources to the small business owners and entrepreneurs of Oakland who need it the most especially now.
# e: Karely Ordaz t chief of staff at the unity Council, on behalf of the organization, we would like to thank the Ofcy Grantee Committee
# person_ent None
#                                                  text  \
# 0   Good morning. As you said, I'm a downtown resi...
# 1   Down morning. I'm chair of tree pack. It's dis...
# 2   So Doug and Andrew if you are out there, call ...
# 3   Thank you. Hi, I just want to bring attention ...
# 4   Yes, I'm here. I'm unmuted, it appears. Yes. O...
# 5   Good afternoon, Council. Thank you for the cha...
# 6   Good morning, Pete her. Good morning. I'm in d...
# 7   Jacob, good morning. Hi. I'm Jacob sheer, Orga...
# 8   Good morning. I am Madison, resident of distri...
# 9   Good morning. I want to address your agenda it...
# 10  Good morning. My name is Paul Casey and I have...
# 11  My name is Catherine Six and I'm the executive...
# 12  Hello, councilman Hollander. Another members o...
# 13  My name is Andrea Diggs. I am the executive di...
# 14  Good evening. I would like to begin tonight by...
# 15  How y'all doing every one of you who know me B...
# 16  Hello.  I live with my family and district 7 a...
# 17  Hello, my name is Steven Bartlett. And I'm her...
# 18  Good afternoon, Greg McConnell, I'm here on be...
# 19  My name is Gamila, I have times and I'm an Org...
# 20  My name is Carmen, I live director of housing ...
# 21  Efz Ning, members of the Oakland City Council,...
# 22  My name is Juanita Douglas t senior constructi...
# 23  Hi, my name is Liz Suk, I Aoep the executive d...
# 24  Nick Peraino with Seiu 1021. I also want to th...
# 25  Good morning, chair and staff and members of t...
# 26  Hi, everyone, my name is Jessie Nguyen, I'm sp...
# 27  Good afternoon, members of committee, my name ...
#
#                                       predicted_ent_1  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Richard Ellison. I'm a retired community colle...
# 3                                                 NaN
# 4                                                 NaN
# 5   Christy Heffaker. And I have proudly worked fo...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10        Paul Casey and I have lived in West Seattle
# 11  Catherine Six and I'm the executive director o...
# 12                                                NaN
# 13  Andrea Diggs. I am the executive director of S...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  Steven Bartlett. And I'm here, representing th...
# 18                                                NaN
# 19  Legalize marijuana and wanted this money to pe...
# 20  Carmen, I live director of housing at the East...
# 21  Lee and I am a member of the International lon...
# 22  Juanita Douglas t senior construction manager ...
# 23  BAS and her two years of work on bringing this...
# 24  Danny comment that I'm a small property owner,...
# 25                                                NaN
# 26  Jessie Nguyen, I'm speaking as a district 2 re...
# 27  Karely Ordaz t chief of staff at the unity Cou...
#
#           named_entity_type_1  \
# 0                         NaN
# 1                         NaN
# 2                      PERSON
# 3                         NaN
# 4                         NaN
# 5   PERSON-AFFLIATED-WITH-ORG
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                     PERSON
# 11                     PERSON
# 12                        NaN
# 13                     PERSON
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                     PERSON
# 18                        NaN
# 19                     PERSON
# 20  PERSON-AFFLIATED-WITH-ORG
# 21                     PERSON
# 22                     PERSON
# 23                     PERSON
# 24                     PERSON
# 25                        NaN
# 26                     PERSON
# 27                     PERSON
#
#                                       predicted_ent_2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Flanigan, please Unmute yourself, you - may be...
# 20                                  Opd an additional
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
#
#           named_entity_type_2
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19  PERSON-AFFLIATED-WITH-ORG
# 20                     PERSON
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN

# %%
# model evaluation after the wrapper function

model_evaluation_exact_span(truth_df, new_ner_df)
# Out:
# 32.14% of the ground truth dataset was predicted correctly.
